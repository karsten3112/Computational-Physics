# %%
import matplotlib.pyplot as plt
from matplotlib import animation
import numpy as np
from scipy.integrate import solve_ivp
from scipy.optimize import fsolve
from scipy.integrate import quad
from scipy import special
from classes import P_dist_handler, H_pot
plt.rc('animation', html='jshtml')

# %%
def proposal_func1(x, delta=0.1): #LAV BREDDEN AF ALLE BINS FAST; GØR DET NEMMERE AT SE DYNAMIKKEN
    return x + delta*np.random.randn(1)

p_handlers = []

pot = H_pot(T=0.15, k=1.0,x_0=0.0)
points = [100, 1000, 10000, 100000]
for N in points:
    p_handler = P_dist_handler(x_min=-1.0, x_max=1.0, N=N, proposal_func=proposal_func1)
    p_handlers.append(p_handler)

# %%
fig, axs= plt.subplots(1, 4, figsize=(13,4))
for ax, p_handler in zip(axs, p_handlers):
    pot.clear_p_handler(new_p_handler=p_handler)
    print(pot.get_v_avg)
    pot.plot(ax)
# Out:
# We did metro-montecarlo
# 0.6530169461867529
# We did metro-montecarlo
# 0.34339883961659556
# We did metro-montecarlo
# 0.32964212676204063
# We did metro-montecarlo
# 0.5152468604770823

# %%
def proposal_func1(x, delta=2.0):
    return x + delta*np.random.randn(1)

p_handlers = []

pot = H_pot(T=0.15, k=1.0,x_0=0.0)
points = [100, 1000, 10000, 100000]
for N in points:
    p_handler = P_dist_handler(x_min=-1.0, x_max=1.0, N=N, proposal_func=proposal_func1)
    p_handlers.append(p_handler)

# %%
fig, axs= plt.subplots(1, 4, figsize=(13,4))
for ax, p_handler in zip(axs, p_handlers):
    pot.clear_p_handler(new_p_handler=p_handler)
    print(pot.get_v_avg)
    pot.plot(ax)
# Out:
# We did metro-montecarlo
# 0.4264714963715284
# We did metro-montecarlo
# 0.5732710527535749
# We did metro-montecarlo
# 0.5259185261402477
# We did metro-montecarlo
# 0.5527043789143048

# %%
def proposal_func2(x, x_min=-2.0, x_max=2.0):
    return x_min + (x_max-x_min)*np.random.rand(1)

p_handlers = []

pot = H_pot(T=0.15, k=1.0,x_0=0.0)
points = [100, 1000, 10000, 100000]
for N in points:
    p_handler = P_dist_handler(x_min=-1.0, x_max=1.0, N=N, proposal_func=proposal_func2)
    p_handlers.append(p_handler)

# %%
fig, axs= plt.subplots(1, 4, figsize=(13,4))
for ax, p_handler in zip(axs, p_handlers):
    pot.clear_p_handler(new_p_handler=p_handler)
    print(pot.get_v_avg)
    pot.plot(ax)
# Out:
# We did metro-montecarlo
# 0.48286624059520517
# We did metro-montecarlo
# 0.4478540762484519
# We did metro-montecarlo
# 0.4584858714692555
# We did metro-montecarlo
# 0.4553428141438895
